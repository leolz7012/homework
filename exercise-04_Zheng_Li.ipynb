# %% [markdown]
# # Exercise 04 - Due Friday, October 21 at 12pm
#
# *Objectives*: Gain experience loading a CSV dataset into a database model you define yourself and using SQL to explore its contents. Explore the data by writing and executing a number of SQL queries using common syntax and functions and describing your findings.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries in the space provided, unless a text answer is requested. Results should be correct, according to the embedded tests. The notebook itself should be completely reproducible; from start to finish, another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Deadline*: Friday, October 21, 12pm. Submit your notebook to Blackboard and push it to your GitHub repository.
#
# ## Setup - obtain data and create database
#
# The US City Open Data Census has data on [restaurant inspections from all over the country](http://us-city.census.okfn.org/dataset/food-safety).  Let's take a look at data from Albuquerque.  *Note*: metadata and other details for this dataset are available at http://data.cabq.gov/business/foodinspections/.
#
# Fyi, to save you a step, I've converted this file into a clean CSV file by using the `dos2unix` command to change its line endings and to switch it to use commas instead of tabs using `csvformat -t inputfile.csv > outputfile.csv`.
#
# First we download the dataset:

# %%
# !wget https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Out:
# --2016-10-24 06:34:42--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5025226 (4.8M) [text/plain]
# Saving to: ‘abq-food-inspections-fy2010.csv’
#
# abq-food-inspection 100%[=====================>]   4.79M  --.-KB/s   in 0.1s
#
# 2016-10-24 06:34:42 (39.9 MB/s) - ‘abq-food-inspections-fy2010.csv’ saved [5025226/5025226]

# %% [markdown]
# ## Problem 1 - examine the data (35 points)
#
# Use `csvstat` and other tools as you see fit and observe its contents.  Review the metadata definitions linked to above.  Describe what you see:  What do all the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some complications or questions you would like to ask?

# %% [markdown]
# Insert a combination of code and text/markdown cells here to review the data and describe what you find.

# %%
# !csvstat 'abq-food-inspections-fy2010.csv'
# Out:
#   1. FACILITY_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2615
# 	5 most frequent values:
# 		SMITHS FOOD AND DRUG CENTERS INC:	154
# 		ISOTOPES PARK - OVATIONS:	93
# 		PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR:	85
# 		ISLETA AMPHITHEATER:	68
# 		ECHO INC:	68
# 	Max length: 77
#   2. FACILITY_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 13
# 	Max: 101482
# 	Sum: 820405773
# 	Mean: 46730.79135338346
# 	Median: 50866.0
# 	Standard Deviation: 32659.794578837962
# 	Unique values: 2835
# 	5 most frequent values:
# 		46323:	93
# 		65863:	85
# 		80949:	68
# 		32817:	68
# 		91825:	66
#   3. SITE_ADDRESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2456
# 	5 most frequent values:
# 		1601 AVENIDA CESAR CHAVEZ SE:	94
# 		644 OLD COORS BLVD SW:	85
# 		8601 CENTRAL AV NE:	77
# 		2200 SUNPORT BLVD SE:	75
# 		5210 CENTRAL AV SE:	73
# 	Max length: 35
#   4. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Values: ALBUQUERQUE
#   5. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Values: 87, NM
#   6. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 48
# 	5 most frequent values:
# 		87110:	1996
# 		87108:	1976
# 		87102:	1601
# 		87106:	1568
# 		87109:	1552
# 	Max length: 10
#   7. OWNER_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 11
# 	Max: 87302
# 	Sum: 644760848
# 	Mean: 36725.953975848715
# 	Median: 33747.0
# 	Standard Deviation: 29428.207216739836
# 	Unique values: 1892
# 	5 most frequent values:
# 		1838:	792
# 		3537:	321
# 		1272:	228
# 		36280:	156
# 		80274:	155
#   8. OWNER_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1852
# 	5 most frequent values:
# 		APS:	792
# 		SMITHS FOOD AND DRUG CENTERS INC:	321
# 		CIRCLE K STORES INC:	277
# 		ALBERTSONS:	228
# 		WAL MART STORES EAST  LP:	156
# 	Max length: 82
#   9. NATURE_OF_BUSINESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 594
# 	5 most frequent values:
# 		RESTAURANT:	4994
# 		FOOD SERVICE:	691
# 		GROCERY:	618
# 		BAR/RESTAURANT:	508
# 		APS SCHOOL FOOD SERVICE:	470
# 	Max length: 25
#  10. STREET_NUMBER
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1349
# 	5 most frequent values:
# 		6600:	216
# 		10000:	152
# 		300:	143
# 		2200:	127
# 		8100:	125
# 	Max length: 7
#  11. STREET_NAME
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		CENTRAL:	1898
# 		MENAUL:	928
# 		COORS:	918
# 		MONTGOMERY:	727
# 		SAN MATEO:	707
# 	Max length: 24
#  12. STREET_TYPE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 13
# 	5 most frequent values:
# 		BLVD:	7636
# 		AV:	3005
# 		ST:	2065
# 		RD:	1900
# 		DR:	995
# 	Max length: 4
#  13. POST_DIRECTIONAL
# 	<class 'str'>
# 	Nulls: True
# 	Values: SW, N, SE, NE, NW
#  14. PHONE
# 	<class 'int'>
# 	Nulls: True
# 	Min: 2471094
# 	Max: 505345566137310
# 	Sum: 2608539289633190
# 	Mean: 161719732773.29138
# 	Median: 5053454060.0
# 	Standard Deviation: 8895791545525.992
# 	Unique values: 2279
# 	5 most frequent values:
# 		9153321301:	101
# 		3037929467:	100
# 		5052224033:	94
# 		3109680646:	85
# 		5052426777:	68
#  15. PROGRAM_CATEGORY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 25
# 	5 most frequent values:
# 		0406:	7969
# 		0601:	1159
# 		0607:	894
# 		0606:	865
# 		0408:	832
# 	Max length: 4
#  16. PROGRAM_CATEGORY_DESCRIPTION
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 24
# 	5 most frequent values:
# 		Food Service Establishment:	7969
# 		Retail -Grocery:	1159
# 		Retail - Self Service & Prepackage Foods:	894
# 		Retail - Prepackage Only:	865
# 		Bar:	832
# 	Max length: 40
#  17. INSPECTION_DATE
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2009-07-01
# 	Max: 2010-06-30
# 	Unique values: 258
# 	5 most frequent values:
# 		2009-12-16:	184
# 		2009-09-10:	159
# 		2009-09-25:	148
# 		2009-11-04:	133
# 		2009-10-01:	131
#  18. INSPECTION_TYPE
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  19. INSPECTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		ROUTINE FOOD INSPECTION:	12439
# 		EMERGENCY RESPONSE:	1987
# 		New Business Inspection:	1005
# 		PRE-OPENING FOOD INSPECTION:	743
# 		ADDITIONAL SERVICE PROVIDED:	439
# 	Max length: 32
#  20. SERIAL_NUM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 9046
# 	5 most frequent values:
# 		DA0045676:	61
# 		DA0047720:	61
# 		DA0059230:	61
# 		DA0047290:	61
# 		DA0045731:	61
# 	Max length: 9
#  21. ACTION_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		11:	14080
# 		00:	2800
# 		09:	382
# 		06:	264
# 		10:	21
# 	Max length: 2
#  22. ACTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		APPROVED:	14080
# 		NON-GRADED:	2800
# 		ANNUAL STICKER ISSUED:	382
# 		UNSATISFACTORY:	264
# 		ANNUAL STICKER NOT ISSUED:	21
# 	Max length: 34
#  23. RESULT_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		03:	14389
# 		00:	2416
# 		05:	214
# 		22:	142
# 		18:	104
# 	Max length: 2
#  24. RESULT_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		IN COMPLIANCE:	14389
# 		NOT APPLICABLE:	2416
# 		DOWNGRADE:	214
# 		OUT OF BUSINESS:	142
# 		TRAINING RECEIVED:	104
# 	Max length: 37
#  25. VIOLATION_CODE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 128
# 	5 most frequent values:
# 		55:	6348
# 		00:	3429
# 		68:	1658
# 		42:	487
# 		35:	441
# 	Max length: 10
#  26. VIOLATION_DESC
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 70
# 	5 most frequent values:
# 		Additional Comments:	6353
# 		No Violations Found:	3434
# 		Delivered Informational Brochure:	1657
# 		Plumbing: Improperly installed/maintained/supplied:	492
# 		Non-Food contact surfaces:	446
# 	Max length: 50
#  27. INSPECTION_MEMO
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 17556

# %%
Meanings of Columns:
    The 1st column means name of the facility where the inspection occurred
    The 2nd column means the unique identifier (key) of the facility where the inspection occurred
    The 3rd column means street address of the facility where the inspection occurred
    The 4th column means city of the facility where the inspection occurred
    The 5th column means state of the facility where the inspection occurred
    The 6th column means zip of the facility where the inspection occurred
    The 7th column means the unique identifier (key) of the Owner of the facility where the inspection occurred at the time of the inspection
    The 8th column means name of the Owner of the facility where the inspection occurred at the time of the inspection
    The 9th column means the type of business, originally for internal use only, provides information about the business
    The 10th column means street number of the facility where the inspection occurred
    The 11th column means street name of the facility where the inspection occurred
    The 12th column means street type of the facility where the inspection occurred
    The 13th column means postal direction of the facility where the inspection occurred
    The 14th column means phone number of the facility where the inspection occurred
    The 15th column means Id that indicates the type of facility permit the inspection was performed
    The 16th column means descript of the id that indicates the type of facility 
    The 17th column means date the inspection occurred
    The 18th column means code for type of inspection 
    The 19th column means description of the inspection
    The 20th column means unique ID for the inspection daily activity
    The 21st column means code of the action taken
    The 22nd column means description of the action taken
    The 23rd column means code of the result of the inspection
    The 24th column means description of the result of the inspection
    The 25th column means the code for the violation
    The 26th column means description of the violation that was found
    The 27th column means notes from the inspection made by the inspector
Null Values: 
    There are null values exist in SITE_ADDRESS, NATURE_OF_BUSINESS, STREET_NUMBER, STREET_NAME, STREET_TYPE, POST_DIRECTIONAL,
    PHONE, PROGRAM_CATEGORY_DESCRIPTION, INSPECTION_TYPE, VIOLATION_CODE, VIOLATION_DESC and INSPECTION_MEMO. 
The 20th column interests me the most. I would like to know what does the inspection daily activity mean.

# %% [markdown]
# ## Problem 2 - define a database model and load the data (35 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset into the database and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Insert a combination of code and text/markdown cells here to connect to your database, define your table, load its data, and verify the loaded records.

# %%
# !mv abq-food-inspections-fy2010.csv data.csv

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !createdb -U dbuser exercise4

# %%
# %sql postgresql://dbuser@localhost:5432/exercise4
# Out:
# 'Connected: dbuser@exercise4'

# %%
# !csvsql --db postgresql://dbuser@localhost:5432/exercise4 --insert data.csv

# %%
# %%sql
# SELECT COUNT(*)
# FROM data;
# Out:
# 1 rows affected.
# [(17556,)]

# %%
This matches the result of the csvstat. Therefore, all the data has been loaded correctly.

# %% [markdown]
# ## Problem 3 - explore your data (30 points)
#
# Now that the data is loaded, ask some questions of it!  Identify key variables of interest and note their ranges along with other useful descriptive statistics.  Choose and define a few lines of inquiry, execute queries for each, and describe what you find in your result sets.  Use any query techniques we've seen in class, including aggregate functions, transformations, subqueries, or others as appropriate.
#
# If you find interesting patterns, adding plots to your exploration would be useful.
#
# Insert a combination of code and text/markdown cells here to explore your data.

# %%
I would like to know the most common result of the inspection.

# %%
# %%sql
# SELECT "RESULT_DESC", COUNT(*) AS count
# FROM data
# GROUP BY "RESULT_DESC"
# ORDER BY count DESC;
# Out:
# 19 rows affected.
# [('IN COMPLIANCE', 14389),
#  ('NOT APPLICABLE', 2416),
#  ('DOWNGRADE', 214),
#  ('OUT OF BUSINESS', 142),
#  ('TRAINING RECEIVED', 104),
#  ('PHONE CALL', 90),
#  ('UPGRADE', 69),
#  ('IMMEDIATE CLOSURE', 45),
#  ('NOT IN COMPLIANCE', 24),
#  ('FACILITY CLOSED AT TIME OF INSPECTION', 19),
#  ('RECALL VERIFICATION', 16),
#  ('PERMIT REINSTATEMENT', 11),
#  ('WITNESS TO DESTRUCTION', 5),
#  ('NOTICE', 3),
#  ('EMBARGO', 3),
#  ('PLAN REVIEW -APPROVED', 2),
#  ('PERMIT SUSPENSION', 2),
#  ('PERMISSION TO OPERATE', 1),
#  ('VOLUNTARY CLOSURE', 1)]

# %%
Here is the list of the resturants that are not applicable.

# %%
# %%sql
# SELECT "FACILITY_NAME", "SITE_ADDRESS","CITY", "STATE", "ZIP"
# FROM data
# WHERE "RESULT_DESC" = 'NOT APPLICABLE';
# Out:
# 2416 rows affected.
# [('00BSAY IT WITH CAKE', '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114'),
#  ('328 CHINESE CUISINE', '5617 MENAUL BLVD NE STE A', 'ALBUQUERQUE', 'NM', '87110'),
#  ('66 DINER', '1405 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('7 BAR ELEMENTARY SCHOOL', '4501 SEVEN BAR LOOP NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('7 ELEVEN 700', '1010 YALE BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('7 ELEVEN 702', '10320 CANDELARIA RD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('7 ELEVEN 703', '12000 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('7 ELEVEN 705', '1801 SAN PEDRO DR NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('7 ELEVEN 706', '6201 SAN ANTONIO DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('7 ELEVEN 707', '10324 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('7 ELEVEN 708', '13601 COPPER AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('7 ELEVEN 709', '2120 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('7 ELEVEN 710', '12524 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('7 ELEVEN 712', '5401 KATHRYN AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('7 ELEVEN 714', '1401 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('7 ELEVEN 716', '1800 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('7 ELEVEN 717', '1720 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('7 ELEVEN 718', '2625 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('7 ELEVEN 719', '1111 LOMAS BLVD NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('7 ELEVEN 720', '7525 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('7-UP/RC BOTTLING CO.', '2101 CLAREMONT AV NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('99 BANH SUPERMARKET', '5315 GIBSON BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('99 BANH SUPERMARKET', '5315 GIBSON BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('99 BANH SUPERMARKET', '5315 GIBSON BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('A TEA CO', '3107 EUBANK BLVD NE STE 12', 'ALBUQUERQUE', 'NM', '87111'),
#  ('A-1 ORIENTAL MARKET', '1410 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ACAPULCO MEXICAN RESTAURANT', '2617 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ACE SUSHI   ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ACOMA ELEMENTARY', '11800 PRINCESS JEANNE AV NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('AFC SUSHI AT SMITHS 459', '8100 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('AFC SUSHI AT SMITHS 463', '4800 MCMAHON RD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('AFC SUSHI AT SMITHS 496', '3701 CONSTITUTION AV NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALAM LLC - RETAIL', '2016 CARLISLE BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALAMOSA CHILD DEVELOPMENT CENTER', '6900 GONZALES RD SW A', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALAMOSA ELEMENTARY', '6500 SUNSET GARDEN RD SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('ALB HEIGHTS HEALTHCARE & REHAB', '103 HOSPITAL NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 904', '4950 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 905', '2910 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 911', '2801 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 911', '2801 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 911', '2801 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 911', '2801 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 911', '2801 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ALBERTSONS 915', '6200 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ALBERTSONS 915', '6200 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ALBERTSONS 915', '6200 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ALBERTSONS 915', '6200 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ALBERTSONS 922', '6600 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALBERTSONS 922', '6600 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALBERTSONS 922', '6600 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALBERTSONS 922', '6600 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALBERTSONS 924', '8100 VENTURA ST NE', 'ALBUQUERQUE', 'NM', '871221303'),
#  ('ALBERTSONS 924', '8100 VENTURA ST NE', 'ALBUQUERQUE', 'NM', '871221303'),
#  ('ALBERTSONS 924', '8100 VENTURA ST NE', 'ALBUQUERQUE', 'NM', '871221303'),
#  ('ALBERTSONS 924', '8100 VENTURA ST NE', 'ALBUQUERQUE', 'NM', '871221303'),
#  ('ALBERTSONS 928', '11825 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 937', '10131 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 937', '10131 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 937', '10131 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 937', '10131 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 938', '7101 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 939', '12201 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBERTSONS 939', '12201 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBUQ COUNTRY CLUB', '601 LAGUNA BLVD SW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('ALBUQ NURSERY', '1423 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALBUQ PRESS CLUB', '201 HIGHLAND PARK CI SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('ALBUQ PRESS CLUB', '201 HIGHLAND PARK CI SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('ALBUQ SOCIAL CLUB', '4021 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALBUQUERQUE ACADEMY', '6400 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALBUQUERQUE ACADEMY', '6400 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALBUQUERQUE ACADEMY', '6400 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALBUQUERQUE AIRPORT COURTYARD', '1920 YALE BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('ALBUQUERQUE CHRISTIAN SCHOOL', '7201 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALBUQUERQUE CITY LIMITS REST.', '3211 COORS BLVD SW #F4', 'ALBUQUERQUE', 'NM', '87121'),
#  ('ALBUQUERQUE COMFORT SUITES', '5811 SIGNAL AV NE', 'ALBUQUERQUE', 'NM', '87113'),
#  ('ALBUQUERQUE MARRIOTT', '2101 LOUISIANA BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALBUQUERQUE MARRIOTT', '2101 LOUISIANA BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALBUQUERQUE MARRIOTT PYRAMID NORTH', '5151 SAN FRANCISCO DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALISONS HOME STYLE COOKING', '2708 ALISO DR NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('ALL SEASONS CHILD CARE 402', '7700 ZUNI RD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALLIS CAFE', '4420 THE 25 WAY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('ALLSTAR CHILDRENS ACADEMY LLC', '4221 SILVER AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALLSUPS 198', '1605 INDIAN SCHOOL RD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('ALPINE SAUSAGE KITCHEN', '2800 INDIAN SCHOOL RD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('ALVARADO DAY SCHOOL INC', '300 ALVARADO DR SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ALVARADO DAY SCHOOL INC', '300 ALVARADO DR SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('AMA TU CUERPO', '9601 SAGE RD SW STE E', 'ALBUQUERQUE', 'NM', '87121'),
#  ('AMERICAN LEGION POST 100', '424 CANDELARIA RD NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('AMERICAN LEGION POST 13', '1201 MOUNTAIN RD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('AMERICAN LEGION POST 49', '11005 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('AMERICAN LEGION POST 72', '5105 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('AMERICAN LEGION POST 99', '540 LOUISIANA BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('AMERICAS BEST VALUE INN', '601 PAISANO DR NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('ANDALUZ RESTAURANT KITCHEN', '125 2ND ST NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('ANDALUZ RESTAURANT KITCHEN', '125 2ND ST NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('ANNAPURNA CHAI HOUSE', '2201 SILVER SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('ANNIES SOUP KITCHEN', '3107 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('ANODYNE', '409 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('ANTIQUITY RESTAURANT  INC.', '112 ROMERO ST NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('ANTOJITOS LA TIA', '7115 PORTULACA DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ANTOJITOS LA TIA', '7115 PORTULACA DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ANTOJITOS LA TIA', '7115 PORTULACA DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ANTOJITOS LA TIA', '7115 PORTULACA DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ANTOJITOS LA TIA', '7115 PORTULACA DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('APACHE ELEMENTARY', '12800 COPPER AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('APPLE CANYON COMPANY INC', '6025 CORONADO NE STE B', 'ALBUQUERQUE', 'NM', '87109'),
#  ('APPLE CANYON COMPANY INC', '6025 CORONADO NE STE B', 'ALBUQUERQUE', 'NM', '87109'),
#  ('APPLEBEES GRILL AND BAR 6401', '6220 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('APPLEBEES GRILL AND BAR 6401', '6220 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('APPLEBEES GRILL AND BAR 6401', '6220 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('APPLEBEES GRILL AND BAR 6402', '3620 NM 528 NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('APPLEBEES GRILL AND BAR 6402', '3620 NM 528 NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('APPLEBEES GRILL AND BAR 6405', '10895 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('APPLEBEES GRILL AND BAR 6405', '10895 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('APPLEBEES GRILL AND BAR 6406', '2711 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('APPLEBEES GRILL AND BAR 6406', '2711 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('APPLEBEES NEIGHBORHOOD GRILL & BAR', '2600 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('APS CAFETERIA SERV WHSE', '720 RANKIN RD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('APS CENTRAL KITCHEN', '912 OAK ST SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('APS CENTRAL KITCHEN', '912 OAK ST SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('APS SOCCER COMPLEX CONCESSIONS', '8111 RAINBOW RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ARBYS / TJ CINNAMONS', '1416 MERCANTILE AV NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('ARBYS RESTAURANT', '4701 PASEO DEL NORTE NE', 'ALBUQUERQUE', 'NM', '87113'),
#  ('ARBYS ROAST BEEF', '3270 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('ARBYS ROAST BEEF', '1751 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ARIANA HALAL MARKET INC', '607 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('ARIRANG ORIENTAL MARKET', '1826 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ARIRANG ORIENTAL MARKET', '1826 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('ARROYO DEL OSO ELEMENTARY', '6504 HARPER DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('
D NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ("CONGREGATION B'NAI ISRAEL", '4401 INDIAN SCHOOL RD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('COOKIE BY DESIGN', '2125 LOUISIANA BLVD NE STE 170', 'ALBUQUERQUE', 'NM', '87110'),
#  ('COOPERAGE  THE', '7220 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('COOPERAGE  THE', '7220 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('CORNUCOPIA ADULT DAY CARE SRV', '2002 BRIDGE BLVD SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('CORONADO ELEMENTARY', '601 4TH ST NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('COST PLUS IMPORTS', '3301 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('COST PLUS WORLD MARKET', '3601 OLD AIRPORT AV NW STE B', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 1016', '9955 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 1016', '9955 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 1016', '9955 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 1016', '9955 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 1016', '9955 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('COSTCO WHOLESALE 116', '1420 RENAISSANCE BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('COSTCO WHOLESALE 116', '1420 RENAISSANCE BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('COSTCO WHOLESALE CORPORATION', '500 EUBANK BLVD SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('COSTCO WHOLESALE CORPORATION', '500 EUBANK BLVD SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('COUNTRY INN & SUITES', '2601 MULBERRY AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('COURTYARD BY MARRIOTT', '5151 JOURNAL CENTER BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('COVENANT SCHOOL DEL NORTE LLC', '7120 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('CRACKER BARREL OLD COUNTRY 617', '5700 REDLANDS RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('CRACKER BARREL OLD COUNTRY 617', '5700 REDLANDS RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('CRACKER BARREL OLD COUNTRY STR', '5200 SAN ANTONIO DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('CROWNE PLAZA ALBUQUERQUE', '1901 UNIVERSITY BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('CUIDANDO LOS NINOS  INC', '1500 WALTER ST SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('CUP O JOE LLC', '3732 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('CVS PHARMACY INC 8916', '3821 ELLISON DR NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('CVS PHARMACY INC 8918', '4340 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DAIRY QUEEN 8', '4104 LOUISIANA BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DAKINE HAWAIIAN ICE', '4007 CARLISLE BLVD NE APT', 'ALBUQUERQUE', 'NM', '87107'),
#  ('DAMACIOS', '913 SAN PEDRO DR SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('DAYS INN EAST', '10321 HOTEL AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('DBM RESTORATION MINISTRY', '824 SAN MATEO BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('DE COLORES', '112 RIO GRANDE BLVD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('DECA EXPRESS SNACK BAR', '6701 FORTUNA RD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DECA MUSTANG ROUNDUP', '6701 FORTUNA RD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DEES CHEESECAKE FACTORY', '3300 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('DEL NORTE BAPTIST CHURCH', '5800 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DEL NORTE BAPTIST CHURCH', '5800 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DEL NORTE CONFERENCE CENTER', '6100 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DEL NORTE CONFERENCE CENTER', '6100 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DEL NORTE HIGH SCHOOL -APS FOOD SV', '5323 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DEL NORTE SUBWAY', '7120 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DENNIS CHAVEZ ELEMENTARY', '7500 BARSTOW ST NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DENNYS 7884', '5201 SAN ANTONIO DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DESERT RIDGE MIDDLE SCHOOL', '8400 BARSTOW ST NE', 'ALBUQUERQUE', 'NM', '87122'),
#  ('DGS DELI & MARKET', '1418 MARTIN LUTHER KING JR AV NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('DIERSEN CHARITIES INC', '2331 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('DIONS', '121 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DIONS', '121 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DIONS', '10010 COORS BYPASS NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('DIONS', '4717 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('DIONS', '4717 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('DIONS', '8010 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('DIONS', '11000 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('DIONS PIZZA', '4200 MONTANO RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('DIONS PIZZA COMMISSARY', '5388 PAN AMERICAN FWY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DIPPIN DOTS INC', '6600 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DOG HOUSE', '1216 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('DOLLAR GENERAL STORE 10762', '4910 LOMAS BLVD NE STE A', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DOLLAR TREE 2664', '3301 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('DOLLAR TREE 2745', '6300 SAN MATEO BLVD NE STE G', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DOLLAR TREE 3702', '9301 COORS BLVD NW STE B2', 'ALBUQUERQUE', 'NM', '87114'),
#  ('DOLLAR TREE 3892', '120 98TH ST STE B', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DOLLAR TREE 4182', '8102 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87113'),
#  ('DOMINOS', '5109 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('DOMINOS PIZZA', '1209 MENAUL BLVD NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('DOMINOS PIZZA', '12000 CANDELARIA RD NE H', 'ALBUQUERQUE', 'NM', '87112'),
#  ('DOMINOS PIZZA', '2115 VISTA OESTE NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('DONUT MART', '1605 JUAN TABO ST NE STE K & L', 'ALBUQUERQUE', 'NM', '87124'),
#  ('DORADO BAKERY', '2125 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('DOWNS NUTRITION CENTER', '7400 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('DOWNTOWN DISTILLERY', '406 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('DRAGONHORN TAVERN', '2906A JUAN TABO NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('DRURY INN & SUITES ALBUQUERQUE', '4310 THE 25 WAY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DRURY INN & SUITES ALBUQUERQUE', '4310 THE 25 WAY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('DUDS N SUDS', '13160 CENTRAL AV SE B', 'ALBUQUERQUE', 'NM', '87123'),
#  ('DUDS N SUDS', '13160 CENTRAL AV SE B', 'ALBUQUERQUE', 'NM', '87123'),
#  ('DUKE CITY BMX', '1011 BUENA VISTA RD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('DUKE CITY GOURMET', 'ONE CIVIC PLAZA', 'ALBUQUERQUE', 'NM', '87103'),
#  ('DUKE CITY GOURMET', 'ONE CIVIC PLAZA', 'ALBUQUERQUE', 'NM', '87103'),
#  ('DUKE CITY GOURMET', 'ONE CIVIC PLAZA', 'ALBUQUERQUE', 'NM', '87103'),
#  ('DUNKIN DONUTS', '1902 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('DURANES CHILD DEV CENTER', '2436 ZICKERT RD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('DURANES ELEMENTARY', '2436 ZICKERT RD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('EAST GATE KIDS CHILD CARE', '12120 COPPER NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EAST GATE KIDS CHILD CARE', '12120 COPPER NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EAST GATE KIDS CHILD CARE', '12120 COPPER NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EAST HEIGHTS MOOSE LODGE 2241', '12825 SKYLINE RD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EAST HEIGHTS MOOSE LODGE 2241', '12825 SKYLINE RD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EAST OCEAN', '3601 CARLISLE BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('EAST SAN JOSE ELEMENTARY', '415 THAXTON AV SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('EASTERN CHILD DEVELOPMENT CENTER', '5100 EASTERN AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('EAT FIRST CHINESE RESTAURANT', '3250 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('EDMUND G ROSS ELEMENTARY', '6700 PALOMAS AV NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('EDO JAPAN', '10000 COORS BYPASS NW VC6', 'ALBUQUERQUE', 'NM', '87114'),
#  ('EDWARD GONZALES ELEMENTARY SCHOOL', '554 90TH ST SW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('EINSTEIN BROS BAGELS 1193', '2510 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('EINSTEIN BROS BAGELS 1203', '8060 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('EINSTEIN BROS BAGELS 2345', '13170 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('EINSTEIN BROS BAGELS 2378', '5010 CUTLER AV NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('EINSTEIN BROS BAGELS 2645', '11255 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('EISENHOWER MIDDLE SCHOOL', '11001 CAMERO AV NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('EL BRONCO RESTAURANT', '301 OLD COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL MEZQUITE MARKET', '100 98TH ST NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL MEZQUITE MARKET', '100 98TH ST NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL MEZQUITE MARKET', '100 98TH ST NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL MEZQUITE MARKET', '100 98TH ST NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL PATIO RESTAURANT', '142 HARVARD DR SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('EL POLLO REAL COLOMBIANO', '600 LOUISIANA BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('EL POLLO REAL COLOMBIANO', '600 LOUISIANA BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('EL SABOR DE JUAREZ', '3527 GIBSON BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('ILLEGAL VENDORS A3C', None, 'ALBUQUERQUE', 'NM', '87110'),
#  ('EL SARAPE RESTAURANT LLC', '5025 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('EL TACO TOTE MEXICAN GRILL', '111 COORS BLVD NW STE E11', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL TORITO BURRITOS', '305 PENNSYLVANIA ST SE', 'ALBUQUERQUE', 'NM', '871084174'),
#  ('EL VAN VAN', '8516 VISTA CLARA LN SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL VAN VAN', '8516 VISTA CLARA LN SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL VAN VAN', '8516 VISTA CLARA LN SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('EL VIVA MEXICO RESTAURANT', '237 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('ELDORADO HIGH SCHOOL', '11300 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('ELDORADO HIGH SCHOOL', '11300 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('ELDORADO HIGH SCHOOL - DECA', '11300 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('EMERSON CHILD DEVELOPMENT', '620 GEORGIA ST SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('EUBANK ELEMENTARY', '9717 INDIAN SCHOOL RD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('EUGENE FIELD ELEMENTARY', '700 EDITH BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('EVANGEL CHRISTIAN CENTER', '4501 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('EVANGEL CHRISTIAN CENTER', '4501 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('EVANGEL CHRISTIAN CENTER', '4501 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('EVANGEL CHRISTIAN CENTER', '4501 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('FA OOB 12/31/13 PER EHSII TAMIS HASTINGS OUT WEST EATERIES DBA ROPERS RESTAU', '8810 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('FACILITY OOB 2/28/14 PER EHSII RANDY MARTINEZ THE ICE CREAM MAN', '1905 WILMORE ST SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FAIR N SQUARE FOOD STORE', '8020 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('FAIRFIELD INN', '2300 CENTRE AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FAITH LUTHERAN CHURCH', '10000 SPAIN RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('FAMILY DOLLAR STORES NM 5165', '7100 SAN PEDRO DR NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('FAMILY DOLLAR STORES NM 6416', '8117 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('FAMILY DOLLAR STORES OF NM 2827', '11500 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('FAMILY DOLLAR STORES OF NM 2828', '111 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('FAMILY DOLLAR STORES OF NM 2828', '111 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('FAMILY DOLLAR STORES OF NM 2828', '111 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('FAMILY DOLLAR STORES OF NM 3087', '1722 BRIDGE BLVD SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('FAMILY DOLLAR STORES OF NM 4208', '128 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('FAMILY DOLLAR STORES OF NM 5072', '3211 COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('FAMILY DOLLAR STORES OF NM 5120', '110 WYOMING BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('FAMILY DOLLAR STORES OF NM 5178', '1416 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('FAMILY DOLLAR STORES OF NM 5328', '930 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('FAMILY DOLLAR STORES OF NM 6258', '4801 MONTANO RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('FANO BREAD COMPANY', '4605 MCLEOD RD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('FANTASY WORLD KITCHEN', '5000 JEFFERSON ST NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('FARINA PIZZERIA', '510 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('FARMER BROS CO', '5911 OFFICE BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('FARMERS MARKET', '10110 SNOW HEIGHTS NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('FEDERICOS MEXICAN FOOD 2', '1109 JUAN TABO NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('FEDEX KINKOS 1957', '2611 COORS BLVD NE STE B', 'ALBUQUERQUE', 'NM', '87120'),
#  ('FEZ CLUB', '6600 ZUNI RD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('FIRST FRUITS CHRISTIAN ACADEMY', '500 OLIVER ROSS RD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('FIRST PRESBYTERIAN CHURCH', '215 LOCUST NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('FLOWERS BAKING COMPANY OF EL PASO LLC', '8725 BROADWAY BLVD NE', 'ALBUQUERQUE', 'NM', '87105'),
#  ('FLYING STAR 1', '3416 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FLYING STAR 2', '4501 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('FLYING STAR 3', '8001 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('FLYING STAR 4', '4026 RIO GRANDE BLVD NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('FLYING STAR 5', '723 SILVER SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('FLYING STAR 6', '10700 A CORRALES RD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('FRITO LAY INC', '1550 MISSION AV NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('FRONTIER RESTAURANT', '2400 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FRONTIER RESTAURANT', '2400 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FRONTIER RESTAURANT', '2400 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('FRUIT BASKET', '3821 12TH ST NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('FU YUANG KOREAN AND CHINESE CUISINE', '3107 EUBANK AV N #16', 'ALBUQUERQUE', 'NM', '87111'),
#  ('G AND H ORIENTAL MARKET LLC', '129 PENNSYLVANIA NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('GARCIAS KITCHEN', '1113 4TH ST NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('GARCIAS KITCHEN', '1736 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('GARFIELD MARKET', '2628 GARFIELD AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('GAS MAX', '845 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('GECKOS BAR & TAPAS', '3500 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('GECKOS BAR TAPAS 2', '5801 ACADEMY ST NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GEM STATE DISTRIBUTORS INC', '5821 MIDWAY PARK BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GENERAL DISTRIBUTORS INC.', '8225 WASHINGTON ST NE', 'ALBUQUERQUE', 'NM', '87113'),
#  ('GENERAL MILLS INC', '3501 PASEO DEL NORTE NE', 'ALBUQUERQUE', 'NM', '87113'),
#  ('GENGHIS GRILL', '4410 THE 25 WAY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ("GEORGIA O'KEEFFE ELEMENTARY", '11701 SAN VICTORIO AV NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('GIANT 6005', '6100 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GIANT 6015', '3603 NM 528 NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('GIANT 6020', '201 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GIANT 6020', '201 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GIANT 6020', '201 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GIANT 6024', '4720 TRAMWAY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('GIANT 6025', '2930 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('GIANT 6027', '6104 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GIANT 6034', '135 CANDELARIA RD NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('GIANT 6035', '10400 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('GIANT 837', '4300 MONTANO NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('GIANT 840', '1524 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GIANT 841', '924 RIO GRANDE BLVD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('GIANT 843', '6821 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GIANT 844', '2401 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('GIANT 848', '8401 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('GLORIAS NM BURRITOS AND MORE', '927 OLD COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GLORIAS NM BURRITOS AND MORE', '927 OLD COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('GNC STORE 2693', '10000 COORS BYPASS NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('GNC STORE 3685', '8020 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('GNC STORE 404', '6600 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('GNC STORE 6643', '6300 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('GNC STORE 6690', '9311 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('GNC STORE 8785', '5211 OURAY RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('GODIVA CHOCOLATIER INC', '6600 MENAUL BLVD NE STE Q-009', 'ALBUQUERQUE', 'NM', '87110'),
#  ('GOLDEN PRIDE CHICKEN', '5231 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('GOLDEN PRIDE CHICKEN', '3720 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('GOLDEN PRIDE CHICKEN', '1830 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
# ...
#  ('LA PLACITA DINING ROOM', '308 SAN FELIPE ST NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('LA PUERTA DE LOS NINOS', '3001 TRELLIS DR NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('LA QUINTA INNS 4023', '7439 PAN AMERICAN FWY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('LA QUINTA INNS 628', '5241 SAN ANTONIO DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('LA QUINTA INNS 816', '2116 YALE BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LA QUINTA INNS 979', '6101 ILIFF RD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LA QUINTA SUITES', '2011 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('LA RESOLANA LEADERSHIP ACADEMY', '1718 YALE SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LA SALITA', '1217 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('LABATT NEW MEXICO LLC', '221 AIRPORT DR NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LABATT NEW MEXICO LLC', '221 AIRPORT DR NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LABATT NEW MEXICO LLC', '221 AIRPORT DR NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LAS PALOMAS NURSING & REHAB CTR', '8100 PALOMAS AV NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('LAUNCHPAD', '618 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LAURENS HALLMARK', '6300 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('LAVALAND ELEMENTARY', '501 57TH ST NW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('LE CHANTILLY FINE PASTRIES', '8216 MENAUL NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('LEGACY CHURCH CAFE', '7201 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LETTUCE CATER/ JOHNS PLACE', '200 LOMAS BLVD NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LINCOLN LUNCH ROOM - CENTRAL KITCH', '912 LOCUST ST SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LINDYS COFFEE SHOP', '500 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '871023114'),
#  ('LITTLE ANITAS', '10200 CORRALES RD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('LITTLE ANITAS MEXICAN FOOD', '2105 MOUNTAIN RD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('LITTLE ANITAS MEXICAN FOOD', '6501 PARADISE BLVD NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('LITTLE ANITAS MEXICAN FOOD', '2000 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LITTLE CORRAL DAY SCHOOL', '10111 CONSTITUTION AV NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('LITTLE LIGHTS CHILD CARE CTR', '118 JACKSON ST NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('LITTLE RED HAMBURGER HUT', '1501 MOUNTAIN RD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('LITTLE SMOKIES', '722 LOMAS BLVD NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LONE STAR STEAKHOUSE AND SALOON', '10019 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('LONE STAR STEAKHOUSE AND SALOON', '10019 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('LONGFELLOW CHILD DEV CENTER', '400 EDITH BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LONGFELLOW ELEMENTARY', '400 EDITH AV NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LONGFELLOW ELEMENTARY', '400 EDITH AV NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOS ALTOS GOLF CONCESS INC', '9717 COPPER AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('LOS CUATES EAST', '8700 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('LOS CUATES EAST', '8700 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('LOS CUATES NORTH', '4901 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('LOS VOLCANOS SR CENTER', '6500 LOS VOLCANES RD NW', 'ALBUQUERQUE', 'NM', '87108'),
#  ('LOTUS NIGHTCLUB', '211 GOLD AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOUIES MEXICAN RESTAURANT', '622 OLD COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LOUIES PRODUCE', '622 OLD COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('LOVELACE MEDICAL CENTER', '601 DR MARTIN LUTHER KING JR AV NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOVELACE WOMENS HOSPITAL', '4701 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('LOWELL CHILD DEVELOPMENT CENTER', '1700 SUNSHINE TERRACE SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LOWELL CHILD DEVELOPMENT CENTER', '1700 SUNSHINE TERRACE SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LOWES 99 SUPERMARKET', '4701 4TH ST NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('LOWES SUPER SAVE GROCERY 98', '701 11TH ST NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOYAL ORDER OF MOOSE 1517', '2121 EDITH BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOYAL ORDER OF MOOSE 1517', '2121 EDITH BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('LOYOLAS FAMILY RESTAURANT LLC', '4500 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('LUCKY BOY HAMBURGERS', '3521 CONSTITUTION AV NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('LUCKY LOUNGE', '9800 MONTGOMERY BLVD NE 9', 'ALBUQUERQUE', 'NM', '87111'),
#  ('LUCKY LOUNGE', '9800 MONTGOMERY BLVD NE 9', 'ALBUQUERQUE', 'NM', '87111'),
#  ('LUCKY LOUNGE', '9800 MONTGOMERY BLVD NE 9', 'ALBUQUERQUE', 'NM', '87111'),
#  ('LUCKY LOUNGE', '9800 MONTGOMERY BLVD NE 9', 'ALBUQUERQUE', 'NM', '87111'),
#  ('LYNDON B JOHNSON MIDDLE SCHOOL', '6811 TAYLOR RANCH DR NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('MACS LA SIERRA COFFEE SHOP', '6217 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('MACS STEAK N ROUGH', '4515 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MADISON MIDDLE SCHOOL', '3501 MOON ST NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MALARKYS', '25 HOTEL CIR NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('MALONEYS TAVERN', '325 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MANNIES FAMILY RESTAURANT INC', '2900 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MANZANO DECA STORE', '12200 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MANZANO DEL SOL GOOD SAMARITAN VILL', '5201 ROMA AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MANZANO HIGH SCHOOL', '12200 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MANZANO HIGH SCHOOL ACTIVITIES', '12200 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MANZANO HIGH SCHOOL ACTIVITIES', '12200 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MANZANO HIGH SCHOOL ACTIVITIES', '12200 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MANZANO MESA CHILD DEVELOPMENT CTR', '801 ELIZABETH ST SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('MANZANO MESA ELEMENTARY SCHOOL', '801 ELIZABETH BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MANZANO MESA ELEMENTARY SCHOOL', '801 ELIZABETH BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MARBLE BREWERY', '111 MARBLE AV NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MARCELLOS CHOPHOUSE', '2201 Q ST NE STE B', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MARCELLOS CHOPHOUSE', '2201 Q ST NE STE B', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MARIACHI RESTAURANT', '2110 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MARIE HUGHES ELEMENTARY', '5701 MOJAVE ST NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('MARIOS PIZZA', '2401 SAN PEDRO DR NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MARIOS PIZZA & PASTA INC', '11500 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MARISCOS ALTAMAR LLC', '1517 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('MARK TWAIN ELEMENTARY', '6316 CONSTITUTION AV NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MARTINEZ TOWN HOUSE', '808 EDITH BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MARY AND TITOS CAFE', '2711 4TH ST NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('MARY ANN BINFORD ELEMENTARY', '1400 CORRIZ DR SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('MATHESON PARK ELEMENTARY', '10809 LEXINGTON AV NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MAURYA', '110 YALE BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MAX DRIVE NUTRITION', '4400 B WYOMING BLVD NE STE B', 'ALBUQUERQUE', 'NM', '87111-3146'),
#  ('MAX DRIVE NUTRITION', '4400 B WYOMING BLVD NE STE B', 'ALBUQUERQUE', 'NM', '87111-3146'),
#  ('MCALISTERS DELI', '2200 LOUISIANA BLVD NE A', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MCCOLLUM ELEMENTARY', '10900 SAN JACINTO AV NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MCDONALDS', '5001 GIBSON BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MCDONALDS', '301 SAN MATEO BLVD SE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MCDONALDS', '8601 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MCDONALDS', '925 SAN PEDRO NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MCDONALDS', '400 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('MCDONALDS', '8501 GOLF COURSE RD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('MCDONALDS', '1600 ALAMEDA BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('MCDONALDS', '2266 WYOMING BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MCDONALDS 10858', '12601 MONTGOMERY NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MCDONALDS 13697', '5301 QUAIL RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('MCDONALDS 1424', '9515 CANDELARIA RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MCDONALDS 22852', '300 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MCDONALDS 23529', '1523 4TH ST SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('MCDONALDS 30903', '3500 COORS BLVD SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('MCDONALDS 3514', '1501 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('MCDONALDS 3907', '2305 CENTRAL AV NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('MCDONALDS RESTAURANT', '8001 HARPER RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MCDONALDS RESTAURANT', '6200 HOLLY AV', 'ALBUQUERQUE', 'NM', '87113'),
#  ('MCKINLEY MIDDLE SCHOOL', '4500 COMANCHE RD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MCKINLEY MIDDLE SCHOOL', '4500 COMANCHE RD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MCM ELEGANTE', '2020 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('MEALS ON WHEELS', '5901 HARPER DR NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('MEDIA ARTS COLLABORATIVE CHARTER', '4401 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87108'),
#  ('MESA VIEW UNITED METHODIST CHURCH', '4701 MONTANO RD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('MEXICAN FOOD BY MUJERES EN ACCION', '1701 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MEXICO LINDO', '1725 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MICHAEL THOMAS COFFEE CO LLC', '3536 ANDERSON SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MICHAELS ARTS AND CRAFTS 4724', '3701 ELLISON DR NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('MICKS CHILE FIX', '2930 CANDELARIA RD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('MILLYS INC', '2100 CANDELARIA RD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('MILLYS RESTAURANT', '7308 JEFFERSON ST NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('MIMMOS PIZZA', '3301 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87120'),
#  ('MING DYNASTY CHINESE RESTAURANT', '1551 EUBANK NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('MITCHELL ELEMENTARY', '10121 COMANCHE RD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MONICAS EL PORTAL INC', '321 RIO GRANDE BLVD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('MONROES', '1520 LOMAS BLVD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('MONROES', '6051 OSUNA RD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('MONTE CARLO', '3916 CENTRAL AV SW', 'ALBUQUERQUE', 'NM', '87105'),
#  ('MONTE VISTA CHRISTIAN CHURCH', '3501 CAMPUS BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MONTE VISTA DAY CARE CTR', '3208 MONTE VISTA BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MONTE VISTA ELEMENTARY', '3211 MONTE VISTA BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MONTES SUBS N MORE', '2801 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('MONTEZUMA ELEMENTARY', '3100 INDIAN SCHOOL NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('MONTGOMERY CHEVRON', '4401 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('MOR FURNITURE FOR LESS', '4920 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MOR FURNITURE FOR LESS', '4920 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('MOUNTAIN RUN DAIRY QUEEN', '5900 EUBANK BLVD NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('MOVIES 8', '4591 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('MOVIES WEST', '9201 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('MR POWDRELLS BARBEQUE', '11301 CENTRAL AV NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('MR TOKYO JAPANESE RESTAURANT', '11200 MONTGOMERY BLVD NE # 17', 'ALBUQUERQUE', 'NM', '87111'),
#  ('NANTUCKET SHOALS SEAFOOD MARKET', '5415 ACADEMY RD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('NATIVO LODGE', '6000 PAN AMERICAN FWY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('NAVAJO LODGE 863', '1521 BROADWAY BLVD SE', 'ALBUQUERQUE', 'NM', '87102'),
#  ('NELSON MEATS', '929 OLD COORS BLVD SW SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('NELSON MEATS', '929 OLD COORS BLVD SW SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('NEW DRAGON CHINESE RESTAURANT', '9550 SAGE RD SW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('NEW FUTURES SCHOOL', '5400 CUTLER AV NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('NEW MEXICO AIDS SERVICES INC', '625 TRUMAN ST NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('NEW MEXICO TEA COMPANY INC', '1131 MOUNTAIN RD NW STE 2', 'ALBUQUERQUE', 'NM', '87102'),
#  ('NEW MEXICO TEA COMPANY INC', '1131 MOUNTAIN RD NW STE 2', 'ALBUQUERQUE', 'NM', '87102'),
#  ('NEWMAN CENTER', '1815 LAS LOMAS RD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('NICK AND JIMMYS BAR AND GRILL', '5021 PAN AMERICAN FWY NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('NM FOOD DISTRIBUTORS', '3041 UNIVERSITY BLVD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('NOAHS ARK CHILDRENS CENTER', '4525 MORRIS ST NE', 'ALBUQUERQUE', 'NM', '87111'),
#  ('NOB HILL BAR AND GRILL LLC', '3124 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('NORTH HEIGHTS FOOD STORE LLC', '11928 CANDELARIA RD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('NORTH VALLEY LITTLE LEAGUE', '1860 GRIEGOS RD NW', 'ALBUQUERQUE', 'NM', '87197'),
#  ('NORTHEAST CHEVRON', '6940 MONTGOMERY BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('NUTRISHOP', '5010 CUTLER AV NE STE D113', 'ALBUQUERQUE', '87', '87111'),
#  ('ODWALLA INC', '3700 OSUNA RD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('OLD TOWN PIZZA PARLOR', '108 RIO GRANDE BLVD NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('OLD TOWN SNOW CONE FACTORY', '204 SAN FELIPE ST NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('OLIVE GARDEN', '601 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('OLIVE GARDEN 118', '6301 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('OLIVE GARDEN 1602', '10500 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('OLIVE GARDEN 1602', '10500 COORS BYPASS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('OLYMPIA CAFE', '2210 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('OLYMPIA CAFE', '2210 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('ONATE ELEMENTARY', '12415 BRENTWOOD HILLS BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('OOB 02.12.13 PERFECT CUP', '415 SILVER AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('OOB 03/20/12ROCKY MTN CHOCOLATE FACTORY', '303 ROMERO ST NW', 'ALBUQUERQUE', 'NM', '87104'),
#  ('OOB 04.21.14 PWD ROBEKS', '4411 SAN MATEO BLVD NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('OOB 04.22.13 AZUMA SUSHI & TEPPAN', '4701 SAN MATEO NE STE #A', 'ALBUQUERQUE', 'NM', '87110'),
#  ('OOB 05.02.13 PWD QUALITY INN AND SUITES', '6100 ILIFF RD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('OOB 10.30.13 DEL TACO', '6600 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('OOB 10.30.13 DEL TACO 898', '1525 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('OOB 10.30.13 DEL TACO 898', '1525 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87121'),
#  ('OOB 10TH & COAL RESTURANT', '922 COAL AV SW', 'ALBUQUERQUE', 'NM', '87102'),
#  ('OOB 11.19.14 PWD LE PEEP RESTAURANT', '2125 LOUISIANA BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('OOB 12.31.13 PWD LIGHT AND HEALTHY MIRAI EXPRESS', '120 HARVARD RD SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('OOB 1800S MEXICAN GRILL', '515 WYOMING BLVD NE STE A', 'ALBUQUERQUE', 'NM', '87108'),
#  ('OOB 2/26/14ALBERTSONS 908', '13150 CENTRAL AV SE', 'ALBUQUERQUE', 'NM', '87123'),
#  ('OOB 2/26/14PEPSI COLA BOTTLING', '2121 CLAREMONT AV NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('OOB 21ST CENTURY PUBLIC ACADEMY', '3100 MENAUL BLVD NE', 'ALBUQUERQUE', 'NM', '87107'),
#  ('OOB 3.15.13 HOLIDAY INN HOTEL AND SUITES', '5050 JEFFERSON ST NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('OOB 3/20/14 A TASTE OF ITALY', '1945 JUAN TABO BLVD NE', 'ALBUQUERQUE', 'NM', '87112'),
#  ('OOB 4TH STREET BINGO', '6211 4TH ST NW', 'ALBUQUERQUE', 'NM', '87107'),
#  ('OOB 7.10.13 DAYS INN', '2331 CENTRE AV SE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('OOB 7/1/14 CARLISLE 66/SUBWAY', '2137 CARLISLE BLVD NE', 'ALBUQUERQUE', 'NM', '87106'),
#  ('OOB 7/24/14STARBUCKS COFFEE 5362', '5010 CUTLER AV NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('OOB 7/29/13LE CAFE MICHE BISTRO', '10126 COORS BLVD NW', 'ALBUQUERQUE', 'NM', '87114'),
#  ('OOB 8/14/13CIRCLE K 6134', '6121 LOMAS BLVD NE', 'ALBUQUERQUE', 'NM', '87110'),
#  ('OOB 8/14/13LITTLE ANITAS MEXICAN FOOD', '7900 SAN PEDRO NE', 'ALBUQUERQUE', 'NM', '87109'),
#  ('OOB 8/27/13 VALLEY HS ACTIVITIES SNACK BAR', '1505 CANDELARIA RD NW', 'ALBUQUERQUE', 'NM', '87102'),
#  ...]

# %% [markdown]
# ## Bonus (10 points)
#
# We have seen a few simple techniques for normalizing data in class.  Choose a column or set of columns that might be redundant and normalize them out to another table:
#
# * Identify the columns to normalize in the source data table
# * Create one or more new tables to hold the normalized records
# * Extract data into the new tables
# * Re-insert the new foreign key references from the new table into the source table
